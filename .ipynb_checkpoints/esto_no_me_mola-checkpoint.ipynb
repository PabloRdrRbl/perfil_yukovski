# %%
# Recuerda, utilizaremos arrays y pintaremos gráficas.
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
np.loadtxt("psi.dat",delimiter=" ")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-7615b3d7cfd5> in <module>()
# ----> 1 np.loadtxt("psi.dat",delimiter=" ")
#
# /Users/pablordrrbl/anaconda/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     858
#     859             # Convert each value according to its column and store
# --> 860             items = [conv(val) for (conv, val) in zip(converters, vals)]
#     861             # Then pack it according to the dtype's nesting
#     862             items = pack_items(items, packing)
#
# ValueError: could not convert string to float:

# %%
x0 = 0.2
y0 = 0.3 

a = 1
beta = 3.383863361824123

alpha = 0

U = 1

# %%
N_malla = 50

x_max = 8
y_max = 3

x = np.linspace(-x_max, x_max, N_malla)
y = np.linspace(-y_max, y_max, N_malla)

XX, YY = np.meshgrid(x,y)

# %%
#pintamos la malla para verla
plt.figure(figsize=(10,10))
plt.scatter(XX.flatten(), YY.flatten(), marker='.')

# %%
# Circulación que hay que añadir al cilindro para
# que se cumpla la hipótesis de Kutta en el perfil
T = 4 * np.pi * a * U * np.sin(alpha)

# %%
rho = np.sqrt(np.power((XX-x0),2)+np.power((YY-y0),2))
theta = np.arctan((YY-y0)/(XX-x0))

psi = (rho * np.sin(theta-alpha) - np.sin(theta-alpha)/rho) * U + (np.log(abs(rho))*T)/(2*np.pi)

# %%
#lo visulaizamos
plt.figure('lineas de corriente', figsize=(10,10))

plt.contour(XX, YY, psi, np.linspace(-5,5,50))
plt.grid()
plt.gca().set_aspect(1)

# %%
Xc = x0 + a * np.cos(theta)
Yc = y0 + a * np.sin(theta)

# %%
#ponemos el cilindro encima
plt.figure('flujo cilindro', figsize=(10,10))

plt.contour(XX, YY, psi, np.linspace(-5,5,50), colors=['blue', 'blue'])
plt.grid()
plt.gca().set_aspect(1)

p = plt.Polygon(list(zip(Xc, Yc)), color="#cccccc", zorder=3)
plt.gca().add_patch(p)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-9-a1b007d15df8> in <module>()
#       6 plt.gca().set_aspect(1)
#       7
# ----> 8 p = plt.Polygon(list(zip(Xc, Yc)), color="#cccccc", zorder=3)
#       9 plt.gca().add_patch(p)
#
# /Users/pablordrrbl/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in __init__(self, xy, closed, **kwargs)
#     856         Patch.__init__(self, **kwargs)
#     857         self._closed = closed
# --> 858         self.set_xy(xy)
#     859
#     860     def get_path(self):
#
# /Users/pablordrrbl/anaconda/lib/python2.7/site-packages/matplotlib/patches.pyc in set_xy(self, xy)
#     924             if len(xy) > 2 and (xy[0] == xy[-1]).all():
#     925                 xy = xy[:-1]
# --> 926         self._path = Path(xy, closed=self._closed)
#     927
#     928     _get_xy = get_xy
#
# /Users/pablordrrbl/anaconda/lib/python2.7/site-packages/matplotlib/path.pyc in __init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     149             codes[-1] = self.CLOSEPOLY
#     150
# --> 151         assert vertices.ndim == 2
#     152         assert vertices.shape[1] == 2
#     153
#
# AssertionError:
